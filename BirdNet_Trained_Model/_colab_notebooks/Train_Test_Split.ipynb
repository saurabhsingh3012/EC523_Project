# %% [markdown]
# To Split audio data into Train-Test data sets:
#
# - Use traintestsplit from sklearn and create a vector containing 80% Train / 20% Split
# - Then using the file IDs, create train test
#
# NOTE: Due to brittleness of BirdNet data loading scripts Saurbah and Ajay ended up having to write a script to move the files into folders with the folder names being the labels.
#
# > Indented block

# %%
import os, sys , glob, math
import warnings
import shutil
warnings.filterwarnings(action='ignore')
import argparse
import pandas as pd
import seaborn as sns; sns.set(style='whitegrid')
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from PIL import Image
from tqdm import tqdm,tnrange,tqdm_notebook
import pickle
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/BirdNET-Analyzer/
# Out:
# /content/drive/MyDrive/BirdNET-Analyzer

# %%
Path = 'ny_metadata.csv'

df = pd.read_csv(Path)

df.sp.unique()

df
# Out:
#           id        gen          sp  ssp  group                en  \
# 0       1142  Meleagris   gallopavo  NaN  birds       Wild Turkey
# 1     720924     Branta  canadensis  NaN  birds      Canada Goose
# 2     711380     Branta  canadensis  NaN  birds      Canada Goose
# 3     608355     Branta  canadensis  NaN  birds      Canada Goose
# 4     606300     Branta  canadensis  NaN  birds      Canada Goose
# ...      ...        ...         ...  ...    ...               ...
# 3830  161892    Mystery     mystery  NaN  birds  Identity unknown
# 3831  154576    Mystery     mystery  NaN  birds  Identity unknown
# 3832  154519    Mystery     mystery  NaN  birds  Identity unknown
# 3833  144437    Mystery     mystery  NaN  birds  Identity unknown
# 3834  128926    Mystery     mystery  NaN  birds  Identity unknown
#
#                      rec            cnt  \
# 0              Don Jones  United States
# 1     Thomas Ryder Payne         Canada
# 2              Jim Berry  United States
# ...

# %%
y_train = np.array([df.id,df.sp]).T

xtrain, xtest, ytrain, ytest = train_test_split(df.id, df.sp, test_size=0.20, random_state=0)

# %%
print(xtest)
# Out:
# 1077    470005
# 1042    135072
# 3353    244029
# 1764     67170
# 2911    679335
#          ...
# 2889    376417
# 914     101645
# 719     182709
# 2005    559544
# 138     352811
# Name: id, Length: 767, dtype: int64

# %%
test_files = xtest
